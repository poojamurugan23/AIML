# %% [markdown]
# <a href="https://colab.research.google.com/github/poojamurugan23/AIML/blob/main/AIML_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy import stats
x=[23,34,5,9,4,5,8,6,12,35,24,21,16,3]
y=[34,32,14,16,17,18,11,19,2,7,9,2,15,1]
slope,intercept,r,p,std_err=stats.linregress(x,y)
def myfunc(x):
  return slope*x + intercept
mymodel=list(map(myfunc,x))
plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression')
plt.plot(x,mymodel)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[23,34,5,9,4,5,8,6,12,35,24,21,16,3]
y=[34,32,14,16,17,18,11,19,2,7,9,2,15,1]
mymodel=np.poly1d(np.polyfit(x,y,3))
myline=np.linspace(1,22,100)
plt.scatter(x,y)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Regression')
plt.plot(myline,mymodel(myline))
plt.show()
